# %%
import sys
import os
from IPython.display import display, HTML

sys.path.append("/g/g16/scullyal/ws/hatchet/")

from util.db import MetadataDB, DataDB
import hatchet as ht

# %%
db = MetadataDB()
ddb = DataDB()

# %%
# ddb.rm([87,88,89,90,91])
ddb.p_md.to_html("raw_db.html")

# %%
# Filter
filter = ddb.p_md.loc[ddb.p_md['keywords'].str.contains('filter', regex=True)]

# Aggregrate
agg = filter.groupby(['run_id', 'keywords']).mean()

# Join
agg_md = agg.join(db.p_md, on='md_id')

# Sort
agg_md.sort_values(by=['callsites'], inplace=True)

# Output
display(HTML(agg_md.to_html()))
agg_md.to_html("pre_opti_filter.html")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>md_id</th>
#       <th>runtime</th>
#       <th>callsites</th>
#       <th>filename</th>
#       <th>filepath</th>
#       <th>nodes</th>
#       <th>num-db-files</th>
#       <th>ranks</th>
#       <th>records</th>
#       <th>setname</th>
#       <th>size-on-disk</th>
#       <th>threads</th>
#       <th>filetype</th>
#       <th>other</th>
#     </tr>
#     <tr>
#       <th>run_id</th>
#       <th>keywords</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2a4f88cec88411eaa2e0a4bf0153f749</th>
# ...

# %%
display(HTML(db.p_md.sort_values(["callsites"]).to_html()))
db.p_md.sort_values(["setname","callsites"]).to_html("md.html")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>callsites</th>
#       <th>filename</th>
#       <th>filepath</th>
#       <th>nodes</th>
#       <th>num-db-files</th>
#       <th>ranks</th>
#       <th>records</th>
#       <th>setname</th>
#       <th>size-on-disk</th>
#       <th>threads</th>
#       <th>filetype</th>
#       <th>other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>50</th>
#       <td>81</td>
#       <td>marbl_triple-pt-3D-rztopaz_20200621-014425/triple-pt-strong-scale/NODES.64.RANKS.2304/marbl-out/perf0.cali</td>
#       <td>/usr/workspace/asde/hatchet-datasets-LC-ONLY/marbl-triple-pt-scaling-study-June2020/marbl_triple-pt-3D-rztopaz_20200621-014425/triple-pt-strong-scale/NODES.64.RANKS.2304/marbl-out/perf0.cali</td>
#       <td>64.0</td>
#       <td>NaN</td>
#       <td>2304.0</td>
#       <td>81</td>
#       <td>LC-ONLY</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
db.rm([31])

# %%
directory = "/usr/workspace/asde/hatchet-datasets-LC-ONLY/marbl-triple-pt-scaling-study-June2020/marbl_triple-pt-3D-rztopaz_20200621-014425/triple-pt-strong-scale/"
end = "{}/marbl-out/perf0.cali"


for subd in os.listdir(directory):
    db.single_add_cali(directory+end.format(subd), query, "LC-ONLY", 5)
# Out:
#     callsites                                           filename  \
# 0        2047                 hpctoolkit-kripke-database-2589460
# 1        1492                 hpctoolkit-kripke-database-2589696
# 2        1548                 hpctoolkit-kripke-database-2589363
# 3        2498                 hpctoolkit-kripke-database-2589332
# 4        8549          hpctoolkit-database-amg2013-mvapich2-64-0
# 5        6656      hpctoolkit-database-amg2013-spectrum-mpi-64-0
# 6        3912                 hpctoolkit-kripke-database-2593557
# 7         999           hpctoolkit-database-kripke-mvapich2-64-0
# 8         927       hpctoolkit-database-kripke-spectrum-mpi-64-0
# 9        8083           hpctoolkit-database-lammps-mvapich2-64-0
# 10       9066       hpctoolkit-database-lammps-spectrum-mpi-64-0
# 11      13035          hpctoolkit-database-lammps-mvapich2-125-0
# 12      13448      hpctoolkit-database-lammps-spectrum-mpi-125-0
# ...

# %%
int("ampi")
